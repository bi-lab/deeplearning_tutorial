# %% [markdown]
# # Deep Learning Practice: Object Recognition in an Image with Caffe
# - slightly modified from examples/00-classification.ipynb
# - 2016 April 15, Heo, Min-Oh

# %% [markdown]
# # 1. setup

# %% [markdown]
# * use magic function for interactive mode

# %%
import matplotlib.pyplot as plt
import numpy as np

# display plots in this notebook
# %matplotlib inline

# %% [markdown]
# * To run any command at the system shell, simply prefix it with !

# %%
# !pwd
# Out:
# /opt/caffe

# %% [markdown]
# ## 2. network definition in Caffe: external files

# %% [markdown]
# * .proto : define class and data structures with google protocol buffer (./src/caffe/proto/caffe.proto ), used in compile time
# * .prototxt: used in running time
#     * the net prototxt: define the architecture (and pointing to train/test data)
#     * the solver prototxt: define the learning parameters with google protocol buffer
# * .caffemodel: binary file having neural network parameters

# %%
# !scripts/download_model_binary.py models/bvlc_reference_caffenet
# !ls ./models/bvlc_reference_caffenet/
# Out:
# bvlc_reference_caffenet.caffemodel  readme.md	     train_val.prototxt
# deploy.prototxt			    solver.prototxt

# %%
# !cat ./models/bvlc_reference_caffenet/deploy.prototxt
# !cat ./models/bvlc_reference_caffenet/solver.prototxt
# !cat ./models/bvlc_reference_caffenet/train_val.prototxt
# Out:
# name: "CaffeNet"
# layer {
#   name: "data"
#   type: "Input"
#   top: "data"
#   input_param { shape: { dim: 10 dim: 3 dim: 227 dim: 227 } }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "conv1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "pool1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "norm1"
#   top: "conv2"
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "conv2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "pool2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "norm2"
#   top: "conv3"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8"
#   inner_product_param {
#     num_output: 1000
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8"
#   top: "prob"
# }

# %% [markdown]
# ## 2.1 To draw Network Architecture with caffe.draw

# %% [markdown]
# * graphviz and pydotplus required to run caffe.draw

# %%
from google.protobuf import text_format
from caffe.draw import get_pydot_graph
from caffe.proto import caffe_pb2
from IPython.display import display, Image
# Out:
# /opt/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Net<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /opt/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Blob<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /opt/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Solver<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \

# %%
_net = caffe_pb2.NetParameter()
f = open("./models/bvlc_reference_caffenet/deploy.prototxt")
text_format.Merge(f.read(), _net)
display(Image(get_pydot_graph(_net,"TB").create_png()))

# %% [markdown]
# ## 3. Classification with CLI

# %%
#!/opt/caffe/build/examples/cpp_classification/classification

# !/opt/caffe/build/examples/cpp_classification/classification ./models/bvlc_reference_caffenet/deploy.prototxt \
    ./models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel ./data/ilsvrc12/imagenet_mean.binaryproto \
    ./data/ilsvrc12/synset_words.txt ./examples/images/cat.jpg
# Out:
# ---------- Prediction for ./examples/images/cat.jpg ----------
# 0.3134 - "n02123045 tabby, tabby cat"
# 0.2380 - "n02123159 tiger cat"
# 0.1235 - "n02124075 Egyptian cat"
# 0.1003 - "n02119022 red fox, Vulpes vulpes"
# 0.0715 - "n02127052 lynx, catamount"

# %%
# !python ./python/classify.py --mean_file '' examples/images/cat.jpg output.npy
# Out:
# /opt/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Net<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /opt/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Blob<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /opt/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Solver<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# CPU mode
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0410 16:42:34.823801   173 net.cpp:49] Initializing net from parameters:
# name: "CaffeNet"
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 10
#       dim: 3
#       dim: 227
#       dim: 227
#     }
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "conv1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "pool1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "norm1"
#   top: "conv2"
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "conv2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "pool2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "norm2"
#   top: "conv3"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8"
#   inner_product_param {
#     num_output: 1000
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8"
#   top: "prob"
# }
# I0410 16:42:34.824779   173 layer_factory.hpp:77] Creating layer data
# I0410 16:42:34.824808   173 net.cpp:91] Creating Layer data
# I0410 16:42:34.824817   173 net.cpp:399] data -> data
# I0410 16:42:34.824838   173 net.cpp:141] Setting up data
# I0410 16:42:34.824849   173 net.cpp:148] Top shape: 10 3 227 227 (1545870)
# I0410 16:42:34.824856   173 net.cpp:156] Memory required for data: 6183480
# I0410 16:42:34.824862   173 layer_factory.hpp:77] Creating layer conv1
# I0410 16:42:34.825122   173 net.cpp:91] Creating Layer conv1
# I0410 16:42:34.825139   173 net.cpp:425] conv1 <- data
# I0410 16:42:34.825150   173 net.cpp:399] conv1 -> conv1
# I0410 16:42:34.825230   173 net.cpp:141] Setting up conv1
# I0410 16:42:34.825247   173 net.cpp:148] Top shape: 10 96 55 55 (2904000)
# I0410 16:42:34.825253   173 net.cpp:156] Memory required for data: 17799480
# I0410 16:42:34.825271   173 layer_factory.hpp:77] Creating layer relu1
# I0410 16:42:34.825284   173 net.cpp:91] Creating Layer relu1
# I0410 16:42:34.825290   173 net.cpp:425] relu1 <- conv1
# I0410 16:42:34.825297   173 net.cpp:386] relu1 -> conv1 (in-place)
# I0410 16:42:34.825309   173 net.cpp:141] Setting up relu1
# I0410 16:42:34.825316   173 net.cpp:148] Top shape: 10 96 55 55 (2904000)
# I0410 16:42:34.825322   173 net.cpp:156] Memory required for data: 29415480
# I0410 16:42:34.825328   173 layer_factory.hpp:77] Creating layer pool1
# I0410 16:42:34.825336   173 net.cpp:91] Creating Layer pool1
# I0410 16:42:34.825342   173 net.cpp:425] pool1 <- conv1
# I0410 16:42:34.825350   173 net.cpp:399] pool1 -> pool1
# I0410 16:42:34.825366   173 net.cpp:141] Setting up pool1
# I0410 16:42:34.825374   173 net.cpp:148] Top shape: 10 96 27 27 (699840)
# I0410 16:42:34.825381   173 net.cpp:156] Memory required for data: 32214840
# I0410 16:42:34.825387   173 layer_factory.hpp:77] Creating layer norm1
# I0410 16:42:34.825397   173 net.cpp:91] Creating Layer norm1
# I0410 16:42:34.825402   173 net.cpp:425] norm1 <- pool1
# I0410 16:42:34.825410   173 net.cpp:399] norm1 -> norm1
# I0410 16:42:34.825420   173 net.cpp:141] Setting up norm1
# I0410 16:42:34.825531   173 net.cpp:148] Top shape: 10 96 27 27 (699840)
# I0410 16:42:34.825542   173 net.cpp:156] Memory required for data: 35014200
# I0410 16:42:34.825549   173 layer_factory.hpp:77] Creating layer conv2
# I0410 16:42:34.825562   173 net.cpp:91] Creating Layer conv2
# I0410 16:42:34.825568   173 net.cpp:425] conv2 <- norm1
# I0410 16:42:34.825577   173 net.cpp:399] conv2 -> conv2
# I0410 16:42:34.825916   173 net.cpp:141] Setting up conv2
# I0410 16:42:34.826035   173 net.cpp:148] Top shape: 10 256 27 27 (1866240)
# I0410 16:42:34.826047   173 net.cpp:156] Memory required for data: 42479160
# I0410 16:42:34.826061   173 layer_factory.hpp:77] Creating layer relu2
# I0410 16:42:34.826071   173 net.cpp:91] Creating Layer relu2
# I0410 16:42:34.826077   173 net.cpp:425] relu2 <- conv2
# I0410 16:42:34.826086   173 net.cpp:386] relu2 -> conv2 (in-place)
# I0410 16:42:34.826095   173 net.cpp:141] Setting up relu2
# I0410 16:42:34.826103   173 net.cpp:148] Top shape: 10 256 27 27 (1866240)
# I0410 16:42:34.826109   173 net.cpp:156] Memory required for data: 49944120
# I0410 16:42:34.826115   173 layer_factory.hpp:77] Creating layer pool2
# I0410 16:42:34.826123   173 net.cpp:91] Creating Layer pool2
# I0410 16:42:34.826129   173 net.cpp:425] pool2 <- conv2
# I0410 16:42:34.826138   173 net.cpp:399] pool2 -> pool2
# I0410 16:42:34.826148   173 net.cpp:141] Setting up pool2
# I0410 16:42:34.826156   173 net.cpp:148] Top shape: 10 256 13 13 (432640)
# I0410 16:42:34.826162   173 net.cpp:156] Memory required for data: 51674680
# I0410 16:42:34.826169   173 layer_factory.hpp:77] Creating layer norm2
# I0410 16:42:34.826177   173 net.cpp:91] Creating Layer norm2
# I0410 16:42:34.826184   173 net.cpp:425] norm2 <- pool2
# I0410 16:42:34.826191   173 net.cpp:399] norm2 -> norm2
# I0410 16:42:34.826201   173 net.cpp:141] Setting up norm2
# I0410 16:42:34.826210   173 net.cpp:148] Top shape: 10 256 13 13 (432640)
# I0410 16:42:34.826215   173 net.cpp:156] Memory required for data: 53405240
# I0410 16:42:34.826221   173 layer_factory.hpp:77] Creating layer conv3
# I0410 16:42:34.826231   173 net.cpp:91] Creating Layer conv3
# I0410 16:42:34.826237   173 net.cpp:425] conv3 <- norm2
# I0410 16:42:34.826244   173 net.cpp:399] conv3 -> conv3
# I0410 16:42:34.827798   173 net.cpp:141] Setting up conv3
# I0410 16:42:34.827875   173 net.cpp:148] Top shape: 10 384 13 13 (648960)
# I0410 16:42:34.827883   173 net.cpp:156] Memory required for data: 56001080
# I0410 16:42:34.827899   173 layer_factory.hpp:77] Creating layer relu3
# I0410 16:42:34.827910   173 net.cpp:91] Creating Layer relu3
# I0410 16:42:34.827927   173 net.cpp:425] relu3 <- conv3
# I0410 16:42:34.828037   173 net.cpp:386] relu3 -> conv3 (in-place)
# I0410 16:42:34.828054   173 net.cpp:141] Setting up relu3
# I0410 16:42:34.828063   173 net.cpp:148] Top shape: 10 384 13 13 (648960)
# I0410 16:42:34.828068   173 net.cpp:156] Memory required for data: 58596920
# I0410 16:42:34.828073   173 layer_factory.hpp:77] Creating layer conv4
# I0410 16:42:34.828083   173 net.cpp:91] Creating Layer conv4
# I0410 16:42:34.828089   173 net.cpp:425] conv4 <- conv3
173 net.cpp:148] Top shape: 10 4096 (40960)
# I0410 16:42:34.896536   173 net.cpp:156] Memory required for data: 67946040
# I0410 16:42:34.896543   173 layer_factory.hpp:77] Creating layer drop6
# I0410 16:42:34.896559   173 net.cpp:91] Creating Layer drop6
# I0410 16:42:34.896566   173 net.cpp:425] drop6 <- fc6
# I0410 16:42:34.896574   173 net.cpp:386] drop6 -> fc6 (in-place)
# I0410 16:42:34.896585   173 net.cpp:141] Setting up drop6
# I0410 16:42:34.896594   173 net.cpp:148] Top shape: 10 4096 (40960)
# I0410 16:42:34.896600   173 net.cpp:156] Memory required for data: 68109880
# I0410 16:42:34.896605   173 layer_factory.hpp:77] Creating layer fc7
# I0410 16:42:34.896615   173 net.cpp:91] Creating Layer fc7
# I0410 16:42:34.896621   173 net.cpp:425] fc7 <- fc6
# I0410 16:42:34.896632   173 net.cpp:399] fc7 -> fc7
# I0410 16:42:34.944147   173 net.cpp:141] Setting up fc7
# I0410 16:42:34.944298   173 net.cpp:148] Top shape: 10 4096 (40960)
# I0410 16:42:34.944314   173 net.cpp:156] Memory required for data: 68273720
# I0410 16:42:34.944331   173 layer_factory.hpp:77] Creating layer relu7
# I0410 16:42:34.944347   173 net.cpp:91] Creating Layer relu7
# I0410 16:42:34.944356   173 net.cpp:425] relu7 <- fc7
# I0410 16:42:34.944366   173 net.cpp:386] relu7 -> fc7 (in-place)
# I0410 16:42:34.944382   173 net.cpp:141] Setting up relu7
# I0410 16:42:34.944391   173 net.cpp:148] Top shape: 10 4096 (40960)
# I0410 16:42:34.944397   173 net.cpp:156] Memory required for data: 68437560
# I0410 16:42:34.944404   173 layer_factory.hpp:77] Creating layer drop7
# I0410 16:42:34.944414   173 net.cpp:91] Creating Layer drop7
# I0410 16:42:34.944422   173 net.cpp:425] drop7 <- fc7
# I0410 16:42:34.944432   173 net.cpp:386] drop7 -> fc7 (in-place)
# I0410 16:42:34.944444   173 net.cpp:141] Setting up drop7
# I0410 16:42:34.944453   173 net.cpp:148] Top shape: 10 4096 (40960)
# I0410 16:42:34.944458   173 net.cpp:156] Memory required for data: 68601400
# I0410 16:42:34.944464   173 layer_factory.hpp:77] Creating layer fc8
# I0410 16:42:34.944474   173 net.cpp:91] Creating Layer fc8
# I0410 16:42:34.944481   173 net.cpp:425] fc8 <- fc7
# I0410 16:42:34.944664   173 net.cpp:399] fc8 -> fc8
# I0410 16:42:34.956624   173 net.cpp:141] Setting up fc8
# I0410 16:42:34.956768   173 net.cpp:148] Top shape: 10 1000 (10000)
# I0410 16:42:34.956782   173 net.cpp:156] Memory required for data: 68641400
# I0410 16:42:34.956800   173 layer_factory.hpp:77] Creating layer prob
# I0410 16:42:34.956820   173 net.cpp:91] Creating Layer prob
# I0410 16:42:34.956831   173 net.cpp:425] prob <- fc8
# I0410 16:42:34.956843   173 net.cpp:399] prob -> prob
# I0410 16:42:34.956872   173 net.cpp:141] Setting up prob
# I0410 16:42:34.956882   173 net.cpp:148] Top shape: 10 1000 (10000)
# I0410 16:42:34.956889   173 net.cpp:156] Memory required for data: 68681400
# I0410 16:42:34.956897   173 net.cpp:219] prob does not need backward computation.
# I0410 16:42:34.956902   173 net.cpp:219] fc8 does not need backward computation.
# I0410 16:42:34.956909   173 net.cpp:219] drop7 does not need backward computation.
# I0410 16:42:34.956915   173 net.cpp:219] relu7 does not need backward computation.
# I0410 16:42:34.956923   173 net.cpp:219] fc7 does not need backward computation.
# I0410 16:42:34.956929   173 net.cpp:219] drop6 does not need backward computation.
# I0410 16:42:34.956935   173 net.cpp:219] relu6 does not need backward computation.
# I0410 16:42:34.956943   173 net.cpp:219] fc6 does not need backward computation.
# I0410 16:42:34.956948   173 net.cpp:219] pool5 does not need backward computation.
# I0410 16:42:34.956955   173 net.cpp:219] relu5 does not need backward computation.
# I0410 16:42:34.956961   173 net.cpp:219] conv5 does not need backward computation.
# I0410 16:42:34.956969   173 net.cpp:219] relu4 does not need backward computation.
# I0410 16:42:34.956975   173 net.cpp:219] conv4 does not need backward computation.
# I0410 16:42:34.956982   173 net.cpp:219] relu3 does not need backward computation.
# I0410 16:42:34.956989   173 net.cpp:219] conv3 does not need backward computation.
# I0410 16:42:34.957155   173 net.cpp:219] norm2 does not need backward computation.
# I0410 16:42:34.957171   173 net.cpp:219] pool2 does not need backward computation.
# I0410 16:42:34.957178   173 net.cpp:219] relu2 does not need backward computation.
# I0410 16:42:34.957185   173 net.cpp:219] conv2 does not need backward computation.
# I0410 16:42:34.957192   173 net.cpp:219] norm1 does not need backward computation.
# I0410 16:42:34.957200   173 net.cpp:219] pool1 does not need backward computation.
# I0410 16:42:34.957206   173 net.cpp:219] relu1 does not need backward computation.
# I0410 16:42:34.957211   173 net.cpp:219] conv1 does not need backward computation.
# I0410 16:42:34.957218   173 net.cpp:219] data does not need backward computation.
# I0410 16:42:34.957224   173 net.cpp:261] This network produces output prob
# I0410 16:42:34.957245   173 net.cpp:274] Network initialization done.
# I0410 16:42:35.692327   173 upgrade_proto.cpp:43] Attempting to upgrade input file specified using deprecated transformation parameters: ./python/../models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel
# I0410 16:42:35.692450   173 upgrade_proto.cpp:46] Successfully upgraded file specified using deprecated data transformation parameters.
# W0410 16:42:35.692476   173 upgrade_proto.cpp:48] Note that future Caffe releases will only support transform_param messages for transformation fields.
# I0410 16:42:35.692484   173 upgrade_proto.cpp:52] Attempting to upgrade input file specified using deprecated V1LayerParameter: ./python/../models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel
# I0410 16:42:36.808315   173 upgrade_proto.cpp:60] Successfully upgraded file specified using deprecated V1LayerParameter
# I0410 16:42:37.478643   173 net.cpp:752] Ignoring source layer loss
# Loading file: examples/images/cat.jpg
# Classifying 1 inputs.
# Done in 1.40 s.
# Saving results into output.npy

# %% [markdown]
# NPY file format is binary file format for persisting a single arbitrary NumPy array on disk.
# * link: http://docs.scipy.org/doc/numpy-dev/neps/npy-format.html

# %% [markdown]
# ## 3.1 label check

# %%
import numpy as np
np.load('output.npy')
# Out:
# array([[  3.91652826e-08,   3.71935384e-05,   2.48166401e-07,
#           2.32448500e-07,   1.41762641e-07,   8.28246925e-07,
#           1.27352821e-03,   1.78080318e-05,   1.52511575e-06,
#           5.44954401e-06,   6.82528139e-07,   2.54525048e-07,
#           1.15304339e-07,   8.23316952e-08,   7.07337563e-07,
#           1.64391381e-07,   5.86436961e-08,   7.35244175e-05,
#           1.67900653e-04]], dtype=float32)

# %%
output=np.load('output.npy')
output_prob=output[0]

# %%
labels_file = './data/ilsvrc12/synset_words.txt'
labels = np.loadtxt(labels_file, str, delimiter='\t')

print 'output label:', labels[output_prob.argmax()]

# sort top five predictions from softmax output
top_inds = output_prob.argsort()[::-1][:8]  # reverse sort and take five largest items
print 'probabilities and labels:'
zip(output_prob[top_inds], labels[top_inds])
# Out:
# output label: n02123159 tiger cat
# probabilities and labels:
# [(0.18598148, 'n02123159 tiger cat'),
#  (0.15719818, 'n02123045 tabby, tabby cat'),
#  (0.11859579, 'n02124075 Egyptian cat'),
#  (0.10724328, 'n02127052 lynx, catamount'),
#  (0.067653313, 'n02325366 wood rabbit, cottontail, cottontail rabbit'),
#  (0.06652844, 'n02119789 kit fox, Vulpes macrotis'),
#  (0.049156651, 'n02342885 hamster'),
#  (0.046403576, 'n02119022 red fox, Vulpes vulpes')]

# %% [markdown]
# ## 4. load network and input preprocessing

# %%
import caffe
caffe.set_mode_cpu()

# %%
net = caffe.Net("./models/bvlc_reference_caffenet/deploy.prototxt",
                "./models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel", caffe.TEST)

# %%
# input image
image = caffe.io.load_image('./examples/images/cat.jpg')

plt.imshow(image)

# %%
# load the mean ImageNet image (as distributed with Caffe) for subtraction
mu = np.load('./python/caffe/imagenet/ilsvrc_2012_mean.npy')
mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
print 'mean-subtracted values:', zip('BGR', mu)
# Out:
# mean-subtracted values: [('B', 104.0069879317889), ('G', 116.66876761696767), ('R', 122.6789143406786)]

# %%
# create transformer for the input called 'data'
tfm = caffe.io.Transformer({'data':net.blobs['data'].data.shape})

tfm.set_transpose('data', (2,0,1))  # move image channels to outermost dimension
tfm.set_mean('data', mu)            # subtract the dataset-mean value in each channel
tfm.set_raw_scale('data', 255)      # rescale from [0, 1] to [0, 255]
tfm.set_channel_swap('data', (2,1,0))  # swap channels from RGB to BGR

# %%
np.shape(image)
net.blobs['data'].data.shape
print "original shape: {}, shape in blobs: {}".format(np.shape(image),net.blobs['data'].data.shape)
# Out:
# original shape: (360, 480, 3), shape in blobs: (10, 3, 227, 227)

# %%
tfm_image = tfm.preprocess('data', image)
print(np.shape(tfm_image))

# copy the image data into the memory allocated for the net
net.blobs['data'].data[...] = tfm_image
# Out:
# (3, 227, 227)

# %%
### perform classification
output = net.forward()

output_prob = output['prob'][0]  # the output probability vector for the first image in the batch
print 'predicted class is:', output_prob.argmax()
# Out:
# predicted class is: 281

# %%
print 'output label:', labels[output_prob.argmax()]
# Out:
# output label: n02123045 tabby, tabby cat

# %%
# sort top five predictions from softmax output
top_inds = output_prob.argsort()[::-1][:8]  # reverse sort and take five largest items

print 'probabilities and labels:'
zip(output_prob[top_inds], labels[top_inds])
# Out:
# probabilities and labels:
# [(0.31243679, 'n02123045 tabby, tabby cat'),
#  (0.23797153, 'n02123159 tiger cat'),
#  (0.12387231, 'n02124075 Egyptian cat'),
#  (0.10075705, 'n02119022 red fox, Vulpes vulpes'),
#  (0.070957251, 'n02127052 lynx, catamount'),
#  (0.053997595, 'n02119789 kit fox, Vulpes macrotis'),
#  (0.014484302, 'n02123394 Persian cat'),
#  (0.01132188, 'n04493381 tub, vat')]

# %% [markdown]
# ## 5. Examining intermediate output

# %%
# for each layer, show the output shape
for layer_name, blob in net.blobs.iteritems():
    print layer_name + '\t' + str(blob.data.shape)
# Out:
# data	(10, 3, 227, 227)
# conv1	(10, 96, 55, 55)
# pool1	(10, 96, 27, 27)
# norm1	(10, 96, 27, 27)
# conv2	(10, 256, 27, 27)
# pool2	(10, 256, 13, 13)
# norm2	(10, 256, 13, 13)
# conv3	(10, 384, 13, 13)
# conv4	(10, 384, 13, 13)
# conv5	(10, 256, 13, 13)
# pool5	(10, 256, 6, 6)
# fc6	(10, 4096)
# fc7	(10, 4096)
# fc8	(10, 1000)
# prob	(10, 1000)

# %%
# for each layer, show the parameter shape: [weights, biases]
for layer_name, param in net.params.iteritems():
    print layer_name + '\t' + str(param[0].data.shape), str(param[1].data.shape)
# Out:
# conv1	(96, 3, 11, 11) (96,)
# conv2	(256, 48, 5, 5) (256,)
# conv3	(384, 256, 3, 3) (384,)
# conv4	(384, 192, 3, 3) (384,)
# conv5	(256, 192, 3, 3) (256,)
# fc6	(4096, 9216) (4096,)
# fc7	(4096, 4096) (4096,)
# fc8	(1000, 4096) (1000,)

# %%
def vis_square(data):
    """Take an array of shape (n, height, width) or (n, height, width, 3)
       and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)"""
    
    # normalize data for display
    data = (data - data.min()) / (data.max() - data.min())
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = (((0, n ** 2 - data.shape[0]),
               (0, 1), (0, 1))                 # add some space between filters
               + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    data = np.pad(data, padding, mode='constant', constant_values=1)  # pad with ones (white)
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    plt.imshow(data); plt.axis('off')

# %%
# the parameters are a list of [weights, biases]
filters = net.params['conv1'][0].data
vis_square(filters.transpose(0, 2, 3, 1))

# %%
feat = net.blobs['conv1'].data[0]
vis_square(feat)

# %%
feat = net.blobs['pool5'].data[0]
vis_square(feat)

# %%
feat = net.blobs['fc6'].data[0]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)

# %%
feat = net.blobs['prob'].data[0]
plt.figure(figsize=(15, 3))
plt.plot(feat.flat)
